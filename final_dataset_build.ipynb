# %%
import pandas as pd

# %%
df_main = pd.read_csv("GSAF5.csv")
df_main.columns = df_main.columns.str.strip()

# %%
df_main.shape

# %%
df_main.head()

# %%
df_ludmilla = pd.read_csv("ludmilla_clean_columns.csv")
df_jorge = pd.read_csv("jorge_clean_columns.csv")

# %%
df_ludmilla.shape

# %%
df_jorge.shape

# %%
df_ludmilla.columns

# %%
df_jorge.columns

# %%
df_ludmilla.index.equals(df_jorge.index)

# %%
df_final = pd.concat([df_ludmilla, df_jorge], axis=1)

# %%
df_final.shape

# %%
df_final.columns = df_final.columns.str.replace(" ", "_")

# %%
df_final.columns = df_final.columns.str.strip().str.lower()

# %%
df_final.head()

# %%
df_final.info()

# %%
df_final.to_csv("final_dataset.csv", index=False)

# %%
df_final.isna().sum()
